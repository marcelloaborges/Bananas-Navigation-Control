# %% [markdown]
# # Navigation Project - DRLND
#
# ---
#
# ### 1. Start the Environment

# %%
import numpy as np
import random

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from collections import namedtuple, deque

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !pip -q install ./python

# %%
from unityagents import UnityEnvironment

env = UnityEnvironment(file_name="/data/Banana_Linux_NoVis/Banana.x86_64")

# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: BananaBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 37
#         Number of stacked Vector Observation: 1
#         Vector Action space type: discrete
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# ### 2. Examine the State and Action Spaces

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents in the environment
print('Number of agents:', len(env_info.agents))

# number of actions
action_size = brain.vector_action_space_size
print('Number of actions:', action_size)

# examine the state space 
state = env_info.vector_observations[0]
print('States look like:', state)
state_size = len(state)
print('States have length:', state_size)
# Out:
# Number of agents: 1
# Number of actions: 4
# States look like: [ 1.          0.          0.          0.          0.84408134  0.          0.
#   1.          0.          0.0748472   0.          1.          0.          0.
#   0.25755     1.          0.          0.          0.          0.74177343
#   0.          1.          0.          0.          0.25854847  0.          0.
#   1.          0.          0.09355672  0.          1.          0.          0.
#   0.31969345  0.          0.        ]
# States have length: 37

# %% [markdown]
# ### 3. Agent Setup

# %%
class QNetwork(nn.Module):
    """Actor (Policy) Model."""

    def __init__(self, state_size, action_size, seed, fc1_units=64, fc2_units=64):
        """Initialize parameters and build model.
        Params
        ======
            state_size (int): Dimension of each state
            action_size (int): Dimension of each action
            seed (int): Random seed
        """
        super(QNetwork, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fc1 = nn.Linear(state_size, fc1_units)
        self.fc2 = nn.Linear(fc1_units, fc2_units)
        self.fc3 = nn.Linear(fc2_units, action_size)

    def forward(self, state):
        """Build a network that maps state -> action values."""
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        return self.fc3(x)


class Agent():
    """Interacts with and learns from the environment."""
    def __init__(self, state_size, action_size, seed):
        """Initialize an Agent object.
        
        Params
        ======
            state_size (int): dimension of each state
            action_size (int): dimension of each action
            seed (int): random seed
        """
        self.state_size = state_size
        self.action_size = action_size
        self.seed = random.seed(seed)

        # Q-Network
        self.qnetwork_local = QNetwork(state_size, action_size, seed).to(device)
        self.qnetwork_target = QNetwork(state_size, action_size, seed).to(device)
        self.optimizer = optim.Adam(self.qnetwork_local.parameters(), lr=LR)

        # Replay memory
        self.memory = ReplayBuffer(action_size, BUFFER_SIZE, BATCH_SIZE, seed)
        # Initialize time step (for updating every UPDATE_EVERY steps)
        self.t_step = 0
    
    def step(self, state, action, reward, next_state, done):
        # Save experience in replay memory
        self.memory.add(state, action, reward, next_state, done)

        # Learn every UPDATE_EVERY time steps.
        self.t_step = (self.t_step + 1) % UPDATE_EVERY
        if self.t_step == 0:
            # If enough samples are available in memory, get random subset and learn
            if len(self.memory) > BATCH_SIZE:
                experiences = self.memory.sample()
                self.learn(experiences, GAMMA)

    def act(self, state, eps=0.):
        """Returns actions for given state as per current policy.
        
        Params
        ======
            state (array_like): current state
            eps (float): epsilon, for epsilon-greedy action selection
        """
        state = torch.from_numpy(state).float().unsqueeze(0).to(device)
        self.qnetwork_local.eval()
        with torch.no_grad():
            action_values = self.qnetwork_local(state)
        self.qnetwork_local.train()

        # Epsilon-greedy action selection
        if random.random() > eps:
            return np.argmax(action_values.cpu().data.numpy())
        else:
            return random.choice(np.arange(self.action_size))

    def learn(self, experiences, gamma):
        """Update value parameters using given batch of experience tuples.

        Params
        ======
            experiences (Tuple[torch.Variable]): tuple of (s, a, r, s', done) tuples 
            gamma (float): discount factor
        """
        states, actions, rewards, next_states, dones = experiences

        # Get max predicted Q values (for next states) from target model
        Q_targets_next = self.qnetwork_target(next_states).detach().max(1)[0].unsqueeze(1)
        # Compute Q targets for current states 
        Q_targets = rewards + (gamma * Q_targets_next * (1 - dones))

        # Get expected Q values from local model
        Q_expected = self.qnetwork_local(states).gather(1, actions)

        # Compute loss
        loss = F.mse_loss(Q_expected, Q_targets)
        # Minimize the loss
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        # ------------------- update target network ------------------- #
        self.soft_update(self.qnetwork_local, self.qnetwork_target, TAU)                     

    def soft_update(self, local_model, target_model, tau):
        """Soft update model parameters.
        θ_target = τ*θ_local + (1 - τ)*θ_target

        Params
        ======
            local_model (PyTorch model): weights will be copied from
            target_model (PyTorch model): weights will be copied to
            tau (float): interpolation parameter 
        """
        for target_param, local_param in zip(target_model.parameters(), local_model.parameters()):
            target_param.data.copy_(tau*local_param.data + (1.0-tau)*target_param.data)


class ReplayBuffer:
    """Fixed-size buffer to store experience tuples."""

    def __init__(self, action_size, buffer_size, batch_size, seed):
        """Initialize a ReplayBuffer object.

        Params
        ======
            action_size (int): dimension of each action
            buffer_size (int): maximum size of buffer
            batch_size (int): size of each training batch
            seed (int): random seed
        """
        self.action_size = action_size
        self.memory = deque(maxlen=buffer_size)  
        self.batch_size = batch_size
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])
        self.seed = random.seed(seed)
    
    def add(self, state, action, reward, next_state, done):
        """Add a new experience to memory."""
        e = self.experience(state, action, reward, next_state, done)
        self.memory.append(e)
    
    def sample(self):
        """Randomly sample a batch of experiences from memory."""
        experiences = random.sample(self.memory, k=self.batch_size)

        states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float().to(device)
        actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).long().to(device)
        rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(device)
        next_states = torch.from_numpy(np.vstack([e.next_state for e in experiences if e is not None])).float().to(device)
        dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float().to(device)
  
        return (states, actions, rewards, next_states, dones)

    def __len__(self):
        """Return the current size of internal memory."""
        return len(self.memory)

# %% [markdown]
# ### 4. Train Agent

# %%
BUFFER_SIZE = int(1e5)  # replay buffer size (1e5)
BATCH_SIZE = 128         # minibatch size (128)
GAMMA = 0.99            # discount factor
TAU = 1e-3              # for soft update of target parameters (1e-3)
LR = 4e-5               # learning rate (4e-5)
UPDATE_EVERY = 1        # how often to update the network

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

agent = Agent(state_size=37, action_size=4, seed=0)

# %%
def dqn(n_episodes=10000, eps_start=.25, eps_end=0.001, eps_decay=0.995):  #1.0 / 0.01 (.3/.001)
    """Deep Q-Learning Agent
    
    Params
    ======
        n_episodes (int): maximum number of training episodes
        max_t (int): maximum number of timesteps per episode
        eps_start (float): starting value of epsilon, for epsilon-greedy action selection
        eps_end (float): minimum value of epsilon
        eps_decay (float): multiplicative factor (per episode) for decreasing epsilon
    """
    scores = []                        # list containing scores from each episode
    scores_window = deque(maxlen=100)  # last 100 scores
    eps = eps_start                    # initialize epsilon
    for i_episode in range(1, n_episodes+1):
        env_info = env.reset(train_mode=True)[brain_name] # reset the environment
        state = env_info.vector_observations[0]           # get initial state
        score = 0
        
        while True:
            action = agent.act(state, eps)        # select an action
            env_info = env.step(action)[brain_name]        # send the action to the environment
            next_state = env_info.vector_observations[0]   # get the next state
            reward = env_info.rewards[0]                   # get the reward
            done = env_info.local_done[0]                  # see if episode has finished
            agent.step(state, action, reward, next_state, done)
            score += reward                                # update the score
            state = next_state                             # roll over the state to next time step
            if done:                                       # exit loop if episode finished
                break
    
        scores_window.append(score)       # save most recent score
        scores.append(score)              # save most recent score
        eps = max(eps_end, eps_decay*eps) # decrease epsilon
        print('Episode {} ... Reward: {:.2f} ... Average Reward: {:.2f}'.format(
            i_episode, score, np.mean(scores_window)))
        
        if np.mean(scores_window)>=13.0:
            print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(
                i_episode-100, np.mean(scores_window)))
            torch.save(agent.qnetwork_local.state_dict(), 'checkpoint.pth')
            break
            
#        if i_episode == 300:
#            UPDATE_EVERY = 1
            
    return scores

scores = dqn()
# Out:
# Episode 1 ... Reward: 12.00 ... Average Reward: 12.00
# Episode 2 ... Reward: 13.00 ... Average Reward: 12.50
# Episode 3 ... Reward: 8.00 ... Average Reward: 11.00
# Episode 4 ... Reward: 9.00 ... Average Reward: 10.50
# Episode 5 ... Reward: 9.00 ... Average Reward: 10.20
# Episode 6 ... Reward: 13.00 ... Average Reward: 10.67
# Episode 7 ... Reward: 11.00 ... Average Reward: 10.71
# Episode 8 ... Reward: 9.00 ... Average Reward: 10.50
# Episode 9 ... Reward: 11.00 ... Average Reward: 10.56
# Episode 10 ... Reward: 11.00 ... Average Reward: 10.60
# Episode 11 ... Reward: 7.00 ... Average Reward: 10.27
# Episode 12 ... Reward: 9.00 ... Average Reward: 10.17
# Episode 13 ... Reward: 16.00 ... Average Reward: 10.62
# Episode 14 ... Reward: 8.00 ... Average Reward: 10.43
# Episode 15 ... Reward: 9.00 ... Average Reward: 10.33
# Episode 16 ... Reward: 12.00 ... Average Reward: 10.44
# Episode 17 ... Reward: 14.00 ... Average Reward: 10.65
# Episode 18 ... Reward: 12.00 ... Average Reward: 10.72
# Episode 19 ... Reward: 17.00 ... Average Reward: 11.05
# Episode 20 ... Reward: 12.00 ... Average Reward: 11.10
# Episode 21 ... Reward: 12.00 ... Average Reward: 11.14
# Episode 22 ... Reward: 6.00 ... Average Reward: 10.91
# Episode 23 ... Reward: 6.00 ... Average Reward: 10.70
# Episode 24 ... Reward: 15.00 ... Average Reward: 10.88
# Episode 25 ... Reward: 9.00 ... Average Reward: 10.80
# Episode 26 ... Reward: 16.00 ... Average Reward: 11.00
# Episode 27 ... Reward: 10.00 ... Average Reward: 10.96
# Episode 28 ... Reward: 15.00 ... Average Reward: 11.11
# Episode 29 ... Reward: 15.00 ... Average Reward: 11.24
# Episode 30 ... Reward: 4.00 ... Average Reward: 11.00
# Episode 31 ... Reward: 14.00 ... Average Reward: 11.10
# Episode 32 ... Reward: 9.00 ... Average Reward: 11.03
# Episode 33 ... Reward: 12.00 ... Average Reward: 11.06
# Episode 34 ... Reward: 13.00 ... Average Reward: 11.12
# Episode 35 ... Reward: 11.00 ... Average Reward: 11.11
# Episode 36 ... Reward: 4.00 ... Average Reward: 10.92
# Episode 37 ... Reward: 11.00 ... Average Reward: 10.92
# Episode 38 ... Reward: 9.00 ... Average Reward: 10.87
# Episode 39 ... Reward: 12.00 ... Average Reward: 10.90
# Episode 40 ... Reward: 13.00 ... Average Reward: 10.95
# Episode 41 ... Reward: 13.00 ... Average Reward: 11.00
# Episode 42 ... Reward: 9.00 ... Average Reward: 10.95
# Episode 43 ... Reward: 11.00 ... Average Reward: 10.95
# Episode 44 ... Reward: 13.00 ... Average Reward: 11.00
# Episode 45 ... Reward: 13.00 ... Average Reward: 11.04
# Episode 46 ... Reward: 15.00 ... Average Reward: 11.13
# Episode 47 ... Reward: 13.00 ... Average Reward: 11.17
# Episode 48 ... Reward: 15.00 ... Average Reward: 11.25
# Episode 49 ... Reward: 8.00 ... Average Reward: 11.18
# Episode 50 ... Reward: 14.00 ... Average Reward: 11.24
# Episode 51 ... Reward: 13.00 ... Average Reward: 11.27
# Episode 52 ... Reward: 13.00 ... Average Reward: 11.31
# Episode 53 ... Reward: 13.00 ... Average Reward: 11.34
# Episode 54 ... Reward: 12.00 ... Average Reward: 11.35
# Episode 55 ... Reward: 8.00 ... Average Reward: 11.29
# Episode 56 ... Reward: 8.00 ... Average Reward: 11.23
# Episode 57 ... Reward: 10.00 ... Average Reward: 11.21
# Episode 58 ... Reward: 12.00 ... Average Reward: 11.22
# Episode 59 ... Reward: 17.00 ... Average Reward: 11.32
# Episode 60 ... Reward: 10.00 ... Average Reward: 11.30
# Episode 61 ... Reward: 8.00 ... Average Reward: 11.25
# Episode 62 ... Reward: 11.00 ... Average Reward: 11.24
# Episode 63 ... Reward: 14.00 ... Average Reward: 11.29
# Episode 64 ... Reward: 10.00 ... Average Reward: 11.27
# Episode 65 ... Reward: 9.00 ... Average Reward: 11.23
# Episode 66 ... Reward: 20.00 ... Average Reward: 11.36
# Episode 67 ... Reward: 9.00 ... Average Reward: 11.33
# Episode 68 ... Reward: 9.00 ... Average Reward: 11.29
# Episode 69 ... Reward: 16.00 ... Average Reward: 11.36
# Episode 70 ... Reward: 9.00 ... Average Reward: 11.33
# Episode 71 ... Reward: 6.00 ... Average Reward: 11.25
# Episode 72 ... Reward: 14.00 ... Average Reward: 11.29
# Episode 73 ... Reward: 10.00 ... Average Reward: 11.27
# Episode 74 ... Reward: 8.00 ... Average Reward: 11.23
# Episode 75 ... Reward: 13.00 ... Average Reward: 11.25
# Episode 76 ... Reward: 12.00 ... Average Reward: 11.26
# Episode 77 ... Reward: 14.00 ... Average Reward: 11.30
# Episode 78 ... Reward: 13.00 ... Average Reward: 11.32
# Episode 79 ... Reward: 10.00 ... Average Reward: 11.30
# Episode 80 ... Reward: 18.00 ... Average Reward: 11.39
# Episode 81 ... Reward: 13.00 ... Average Reward: 11.41
# Episode 82 ... Reward: 15.00 ... Average Reward: 11.45
# Episode 83 ... Reward: 12.00 ... Average Reward: 11.46
# Episode 84 ... Reward: 16.00 ... Average Reward: 11.51
# Episode 85 ... Reward: 13.00 ... Average Reward: 11.53
# Episode 86 ... Reward: 8.00 ... Average Reward: 11.49
# Episode 87 ... Reward: 16.00 ... Average Reward: 11.54
# Episode 88 ... Reward: 11.00 ... Average Reward: 11.53
# Episode 89 ... Reward: 8.00 ... Average Reward: 11.49
# Episode 90 ... Reward: 13.00 ... Average Reward: 11.51
# Episode 91 ... Reward: 11.00 ... Average Reward: 11.51
# Episode 92 ... Reward: 10.00 ... Average Reward: 11.49
# Episode 93 ... Reward: 10.00 ... Average Reward: 11.47
# Episode 94 ... Reward: 12.00 ... Average Reward: 11.48
# Episode 95 ... Reward: 13.00 ... Average Reward: 11.49
# Episode 96 ... Reward: 11.00 ... Average Reward: 11.49
# Episode 97 ... Reward: 14.00 ... Average Reward: 11.52
# Episode 98 ... Reward: 13.00 ... Average Reward: 11.53
# Episode 99 ... Reward: 10.00 ... Average Reward: 11.52
# Episode 100 ... Reward: 14.00 ... Average Reward: 11.54
# Episode 101 ... Reward: 12.00 ... Average Reward: 11.54
# Episode 102 ... Reward: 13.00 ... Average Reward: 11.54
# Episode 103 ... Reward: 12.00 ... Average Reward: 11.58
# Episode 104 ... Reward: 10.00 ... Average Reward: 11.59
# Episode 105 ... Reward: 13.00 ... Average Reward: 11.63
# Episode 106 ... Reward: 12.00 ... Average Reward: 11.62
# Episode 107 ... Reward: 14.00 ... Average Reward: 11.65
# Episode 108 ... Reward: 10.00 ... Average Reward: 11.66
# Episode 109 ... Reward: 13.00 ... Average Reward: 11.68
# Episode 110 ... Reward: 12.00 ... Average Reward: 11.69
# Episode 111 ... Reward: 15.00 ... Average Reward: 11.77
# Episode 112 ... Reward: 13.00 ... Average Reward: 11.81
# Episode 113 ... Reward: 14.00 ... Average Reward: 11.79
# Episode 114 ... Reward: 11.00 ... Average Reward: 11.82
# Episode 115 ... Reward: 12.00 ... Average Reward: 11.85
# Episode 116 ... Reward: 12.00 ... Average Reward: 11.85
# Episode 117 ... Reward: 14.00 ... Average Reward: 11.85
# Episode 118 ... Reward: 12.00 ... Average Reward: 11.85
# Episode 119 ... Reward: 11.00 ... Average Reward: 11.79
# Episode 120 ... Reward: 7.00 ... Average Reward: 11.74
# Episode 121 ... Reward: 14.00 ... Average Reward: 11.76
# Episode 122 ... Reward: 9.00 ... Average Reward: 11.79
# Episode 123 ... Reward: 12.00 ... Average Reward: 11.85
# Episode 124 ... Reward: 16.00 ... Average Reward: 11.86
# Episode 125 ... Reward: 13.00 ... Average Reward: 11.90
# Episode 126 ... Reward: 12.00 ... Average Reward: 11.86
# Episode 127 ... Reward: 14.00 ... Average Reward: 11.90
# Episode 128 ... Reward: 12.00 ... Average Reward: 11.87
# Episode 129 ... Reward: 12.00 ... Average Reward: 11.84
# Episode 130 ... Reward: 22.00 ... Average Reward: 12.02
# Episode 131 ... Reward: 13.00 ... Average Reward: 12.01
# Episode 132 ... Reward: 8.00 ... Average Reward: 12.00
# Episode 133 ... Reward: 11.00 ... Average Reward: 11.99
# Episode 134 ... Reward: 8.00 ... Average Reward: 11.94
# Episode 135 ... Reward: 12.00 ... Average Reward: 11.95
# Episode 136 ... Reward: 13.00 ... Average Reward: 12.04
# Episode 137 ... Reward: 11.00 ... Average Reward: 12.04
# Episode 138 ... Reward: 14.00 ... Average Reward: 12.09
# Episode 139 ... Reward: 15.00 ... Average Reward: 12.12
# Episode 140 ... Reward: 14.00 ... Average Reward: 12.13
# Episode 141 ... Reward: 17.00 ... Average Reward: 12.17
# Episode 142 ... Reward: 19.00 ... Average Reward: 12.27
# Episode 143 ... Reward: 15.00 ... Average Reward: 12.31
# Episode 144 ... Reward: 10.00 ... Average Reward: 12.28
# Episode 145 ... Reward: 20.00 ... Average Reward: 12.35
# Episode 146 ... Reward: 11.00 ... Average Reward: 12.31
# Episode 147 ... Reward: 13.00 ... Average Reward: 12.31
# Episode 148 ... Reward: 21.00 ... Average Reward: 12.37
# Episode 149 ... Reward: 10.00 ... Average Reward: 12.39
# Episode 150 ... Reward: 13.00 ... Average Reward: 12.38
# Episode 151 ... Reward: 13.00 ... Average Reward: 12.38
# Episode 152 ... Reward: 9.00 ... Average Reward: 12.34
# Episode 153 ... Reward: 18.00 ... Average Reward: 12.39
# Episode 154 ... Reward: 16.00 ... Average Reward: 12.43
# Episode 155 ... Reward: 18.00 ... Average Reward: 12.53
# Episode 156 ... Reward: 15.00 ... Average Reward: 12.60
# Episode 157 ... Reward: 13.00 ... Average Reward: 12.63
# Episode 158 ... Reward: 15.00 ... Average Reward: 12.66
# Episode 159 ... Reward: 11.00 ... Average Reward: 12.60
# Episode 160 ... Reward: 15.00 ... Average Reward: 12.65
# Episode 161 ... Reward: 14.00 ... Average Reward: 12.71
# Episode 162 ... Reward: 11.00 ... Average Reward: 12.71
# Episode 163 ... Reward: 12.00 ... Average Reward: 12.69
# Episode 164 ... Reward: 16.00 ... Average Reward: 12.75
# Episode 165 ... Reward: 18.00 ... Average Reward: 12.84
# Episode 166 ... Reward: 12.00 ... Average Reward: 12.76
# Episode 167 ... Reward: 16.00 ... Average Reward: 12.83
# Episode 168 ... Reward: 19.00 ... Average Reward: 12.93
# Episode 169 ... Reward: 13.00 ... Average Reward: 12.90
# Episode 170 ... Reward: 14.00 ... Average Reward: 12.95
# Episode 171 ... Reward: 13.00 ... Average Reward: 13.02
#
# Environment solved in 71 episodes!	Average Score: 13.02

# %%
# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()

# %%
env.close()
